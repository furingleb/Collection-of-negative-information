# %%
import feedparser
import pandas as pd
import openpyxl
import numpy
import datetime as dt
import time
import re

# %%
# %%time

#import feedparser
#import pandas as pd
#import openpyxl
#import numpy
#import datetime as dt
#import re

def cleanhtml(raw_html):
    if len(raw_html)>0:
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, '', raw_html)
        return cleantext
    else:
        return raw_html
    

#Ссылки на RSS каналы
sites = [
'http://www.xakep.ru/articles/rss/default.asp?rss_cat=post' ,
'http://www.xakep.ru/articles/rss/default.asp?rss_cat=news' ,
'http://www.xakep.ru/articles/rss/default.asp?rss_cat=hack' ,
'http://news.ngs.ru/rss/' ,
'http://news.ngs.ru/rss/articles/' ,
'http://news.mail.ru/rss/',
'http://news2.ru/rss.php?order=new' ,
'http://news.tut.by/rss/all.rss' ,
'http://www.rian.ru/export/rss2/index.xml',
'http://www.finmarket.ru/rss.asp',
'http://www.aif.ru/rss/all.php',
'http://www.vesti.ru/vesti.rss',
'http://www.vsesmi.ru/rss/19/',
'http://news.rambler.ru/rss/world/', 
'https://www.banki.ru/xml/news.rss',
'https://newsland.com/exp/rss/all/',
'https://www.ridus.ru/rss/home/',
'https://www.vesti.ru/vesti.rss',
'https://www.pravda.ru/export.xml',
'https://www.pravda.ru/export-news.xml',
'https://www.vbr.ru/rss/rss.xml' ,
'https://www.kommersant.ru/RSS/news.xml' ,
'http://www.kommersant.ru/rss/ogoniok.xml' ,
'http://www.kommersant.ru/RSS/news.xml',
'http://www.vesti.ru/vesti.rss' ,
'http://www.svobodanews.ru/rss/' ,
'http://www.vsesmi.ru/rss/19/' ,  
'http://www.kommersant.ru/RSS/corp.xml' ,
'http://www.fontanka.ru/fontanka.rss' ,
'http://www.gazeta.ru/export/rss/lenta.xml' ,
'http://www.gazeta.ru/export/rss/first.xml' ,
'http://www.gazeta.ru/export/rss/politics.xml' ,
'http://www.gazeta.ru/export/rss/social.xml' ,
'http://www.gazeta.ru/export/rss/money.xml',
'http://www.gazetanv.ru/rss.xml' ,
'http://www.novayagazeta.ru/rss/all.xml' ,
'http://www.lawmix.ru/rss.php' ,
'http://www.banki.ru/xml/news.rss' ,
'http://www.bfm.ru/news.rss?rubric=19' ,
'http://www.kommersant.ru/RSS/money.xml' ,
'http://www.kommersant.ru/rss/weekend.xml' ,
'http://www.life-news.ru/rss.xml' ,
'https://www.vedomosti.ru/rss/rubric/finance/banks' ,
'https://www.vedomosti.ru/rss/rubric/finance/players' ,
'https://www.vedomosti.ru/rss/rubric/finance/insurance' ,
'https://www.vedomosti.ru/rss/rubric/finance/personal_finance' ,
'http://www.vz.ru/export/yandex.xml' ,
'http://www.russ-yug.ru/1.rss' ,
'http://primamedia.ru/export/news.rss',
'https://lenta.ru/rss',
'http://vz.ru/rss.xml' ,
'http://russian.rt.com/rss/' ,
'http://img.lenta.ru/r/EX/import.rss' ,
'http://rostov.ru/rss.xml' ,
'http://kuzbassnews.ru/engine/rss.php' ,
'http://finmarket.ru/rss/mainnews.asp' ,
'http://inosmi.ru/misc/export/xml/rss/translation.xml',
'http://static.feed.rbc.ru/rbc/logical/rbcdaily.ru/daily.rss' ,   
'http://static.feed.rbc.ru/rbc/internal/rss.rbc.ru/rbc.ru/newsline.rss' ,
'http://news.google.com/news?hl=ru&um=1&q=%D0%D2%C1%D7%C1+%C9%CE%D7%C1%CC%C9%C4%CF%D7&ie=windows-1251&output=rss' , 
#######################################################################
'http://news.yandex.ru/politics.rss' ,
'http://news.yandex.ru/world.rss' ,
'http://news.yandex.ru/Moscow/index.rss',
'http://news.yandex.ru/index.rss' ,
'http://news.yandex.ru/Russia/index.rss' ,
'http://news.yandex.ru/incident.rss',
'https://news.yandex.ru/Voronezh/index.rss',
'https://news.yandex.ru/Irkutsk/index.rss',
'https://news.yandex.ru/Chelyabinsk/index.rss',
'https://news.yandex.ru/Saint_Petersburg/index.rss',
'https://news.yandex.ru/world.rss',
'https://news.yandex.ru/index.rss',
'https://news.yandex.ru/internet.rss',
'https://news.yandex.ru/incident.rss',
'https://news.yandex.ru/science.rss',
'https://news.yandex.ru/computers.rss',
'https://news.yandex.ru/finances.rss',
'https://news.yandex.ru/business.rss',
'http://static.feed.rbc.ru/rbc/logical/rbcdaily.ru/daily.rss',
'http://static.feed.rbc.ru/rbc/internal/rss.rbc.ru/rbc.ru/newsline.rss',
'http://news.rambler.ru/rss/world/',
'https://rg.ru/xml/index.xml',
'https://russian.rt.com/rss',
'https://tvernews.ru/daily.rss',
'http://www.finmarket.ru/rss/mainnews.asp',
'http://www.finmarket.ru/rss/analytics.asp',
'http://www.finmarket.ru/rss/experts.asp',
'https://www.finam.ru/analysis/conews/rsspoint',
'https://www.finam.ru/analysis/nslent/rsspoint',
'https://www.finam.ru/international/advanced/rsspoint' , 
'https://bonds.finam.ru/news/today/rss.asp',
'https://bonds.finam.ru/comments/today/rss.asp'
]

#Словарь с ключ/значение на месяца
month = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'June':'06', 
         'July':'07', 'Aug':'08', 'Sept':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

#short-теги которые мы удаляем полностью 
repka = ['<br />', '<br/>','<br>','&gt;', '&quot;','</p>', '<p>','</h3>','<h3>','</strong>', '<strong>','&nbsp;','&laquo;','&raquo;','&mdash;',
         'Читать в блоге', 'Авто-репост.']  

#long-теги которые мы удаляем полностью 
func_el = ['</em>','</a>','</span>','</widget>' ]  
#<img src="***" style="float: left;" />

#Основные ключевые слова для поиска новостей о Сбербанке
sb = ['Сбер', 'Sber']

#Негатив
neg_list = [r'\b[оа][хг]ре[сз]\S*', r'\b[сз][оа]ве[сз]т\S*', r'\bв[оа]р\S*', r'\b[хг]руб\S*', r'\bдебил\S*', 
            r'\bде[сз]инф[оа]рм\S*', r'\bд[оа]бр[оа][сз][оа]ве[сз]тн\S*', r'\bдур\S*',
            r'\b[сз][оа]блужден\S*', r'\bиди[оа]т\S*', r'\bкр[оа]ж\S*', r'\bкр[оа]л\S*', r'\bне [сз][оа]блюд\S*', 
            r'\bбиле[тд]\S* в бу[тд]ущ\S*', r'\bбу[тд]ущ\S* к[oa]пи[тд][oa]л\S*', r'\b[oa]с[oa][гх][oa] [oa]нл[oa]йн', r'\bисж', r'\bнсж']

#Период статей
Data_Before = dt.datetime.strptime('20190101', '%Y%m%d').date() # 1 января 2019
#Data_After = dt.datetime.strptime('20200101', '%Y%m%d').date() # 1 января 2020
Data_Now = dt.date.today() #Сегодняшняя дата

df = pd.DataFrame(columns=['Название источника', 'Ссылка на канал', 'Заголовок', 'Описание', 'Ссылка на новость', 'Дата новости'])
df2 = pd.DataFrame(columns=['Название источника', 'Ссылка на канал', 'Заголовок', 'Описание', 'Ссылка на новость', 'Дата новости'])
df3 = pd.DataFrame(columns=['Название источника', 'Ссылка на канал', 'Заголовок', 'Описание', 'Ссылка на новость', 'Дата новости'])
df4 = pd.DataFrame(columns=['Название источника', 'Ссылка на канал', 'Заголовок', 'Описание', 'Ссылка на новость', 'Дата новости'])

pl_all = 0
for site in sites: #Работаем с каждым сайтом из выборки сайтов
    pk = 0
    
    d = feedparser.parse(site)
    while d.feed == {}:
        d = feedparser.parse(site)
        
    print("\nИдет работа с сайтом: ", site)
    
    d.feed.title = (d.feed.title).replace('<![CDATA[ ','').replace(']]>','')
    print("Наименование канала: \"", (d.feed.title), "\" ")
    #print('Кол-во постов (всего):', len(d.entries))
    for post in range(0,len(d.entries)): # Настраиваем работу с количеством постов (kol_zap)
        
        try:
            date_news = str(d.entries[post].published).split() #Настраиваем корректность даты
            YMD = date_news[3] + month[date_news[2]] + date_news[1]
            date_post = dt.datetime.strptime(YMD, '%Y%m%d').date()
            #print('У поста №',post ,'Дата была', d.entries[post].published, ', дата стала', date_post)
            d.entries[post].published = date_post

            if (Data_Before<= d.entries[post].published <=Data_Now): #Проверяем что наша дата находиться между нашими двумя точками
                pk+=1
                for rep in repka: #Перебираем все short-теги
                    if rep in d.entries[post].description: #Если находим short-теги, то удаляем их
                        d.entries[post].description=(d.entries[post].description).replace(rep,' ')
                df.loc[post+pl_all]=[d.feed.title,d.feed.link,d.entries[post].title,d.entries[post].description,d.entries[post].link,d.entries[post].published] #записываем новыми строками данные 

        except:
            pk+=1
            for rep in repka: #Перебираем все short-теги
                if rep in d.entries[post].description: #Если находим short-теги, то удаляем их
                        d.entries[post].description=(d.entries[post].description).replace(rep,' ')
            df.loc[post+pl_all]=[d.feed.title,d.feed.link,d.entries[post].title,d.entries[post].description,d.entries[post].link,d.entries[post].published] #записываем новыми строками данные 

    pl_all+=pk
    print('Постов найдено ', pk,'!')

#print('\nВсего найдено постов ', pl_all,'!')

#################################################################################################
df.reset_index(inplace=True) #Удаляем старую индексацию
del df['index'] 

for i in range(len(df)):
    df["Описание"][i] = cleanhtml(df["Описание"][i])

##################################################################################################
n = (str(dt.datetime.now()).replace("-","").replace(":","").replace(" ","_"))[:15] 

df.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df.reset_index(inplace=True) #Удаляем старую индексацию
del df['index'] 
df.to_excel('RSS_all_'+ n +'.xlsx') #Сохраняем информацию в первичный файл

print('\nПостов собранно ', len(df),'!')
print('\nФайл сохранен c кодом ', n, ' !')

########################################################_PART_2_####################################################  

for i in range(len(df)-1):
    strok = df["Описание"][i]        
    for s1 in sb: #Проверяем на первое ключевое слово
        if s1.lower() in (strok.lower()):
            
            for  s2 in inp_k2: #Проверяем на второе ключевое слово
                if s2.lower() in (strok.lower()):
                    for neg1 in neg_list: #Проверяем на третье (негативное) слово
                        if neg1.lower() in (strok.lower()):
                            df2=pd.concat([df2,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше 
                         
            for  sl2 in pens_k2: #Проверяем на второе ключевое слово
                if sl2.lower() in (strok.lower()):
                    for neg2 in neg_list: #Проверяем на третье (негативное) слово
                        if neg2.lower() in (strok.lower()):
                            df3=pd.concat([df3,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше    
                        
            for  slo2 in strah_k2: #Проверяем на второе ключевое слово
                if slo2.lower() in (strok.lower()):
                    for neg3 in neg_list: #Проверяем на третье (негативное) слово
                        if neg3.lower() in (strok.lower()):
                            df4=pd.concat([df4,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше 
            
print("Пройден еще один шаг\n")

df2.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df2.reset_index(inplace=True) #Удаляем старую индексацию
del df2['index'] 
print('Удовлетворяют всем условиям: ', len(df2),'!')
df2.to_excel('Инвест продукты_'+ n +'.xlsx')
print("Программа успешно закончила работу! В части 'Инвест продукты'")

df3.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df3.reset_index(inplace=True) #Удаляем старую индексацию
del df3['index'] 
print('Удовлетворяют всем условиям: ', len(df3),'!')
df3.to_excel('Пенсия_'+ n +'.xlsx')
print("Программа успешно закончила работу! В части 'Пенсия'")

df4.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df4.reset_index(inplace=True) #Удаляем старую индексацию
del df4['index'] 
print('Удовлетворяют всем условиям: ', len(df4),'!')
df4.to_excel('Страховка_'+ n +'.xlsx')
print("Программа успешно закончила работу! В части 'Страховка'")
# Out:
# Идет работа с сайтом:  http://www.xakep.ru/articles/rss/default.asp?rss_cat=post
# Наименование канала: " «Хакер» "
# Постов найдено  10 !
#
# Идет работа с сайтом:  http://www.xakep.ru/articles/rss/default.asp?rss_cat=news
# Наименование канала: " «Хакер» "
# Постов найдено  10 !
#
# Идет работа с сайтом:  http://www.xakep.ru/articles/rss/default.asp?rss_cat=hack
# Наименование канала: " «Хакер» "
# Постов найдено  10 !
#
# Идет работа с сайтом:  http://news.ngs.ru/rss/
# Наименование канала: " НГС.НОВОСТИ "
# Постов найдено  40 !
#
# Идет работа с сайтом:  http://news.ngs.ru/rss/articles/
# Наименование канала: " НГС.НОВОСТИ - Статьи "
# Постов найдено  10 !
#
# Идет работа с сайтом:  http://news.mail.ru/rss/
# Наименование канала: " Новости Mail.ru: Главные новости "
# Постов найдено  20 !
#
# Идет работа с сайтом:  http://news2.ru/rss.php?order=new
# Наименование канала: " Последние новости сегодня / news2.ru "
# Постов найдено  26 !
#
# ...

# %%
###########################################################_PART_1_###################################################  

for ii in range(len(df)): #Перебираем все строки ДатаФрейма
    stroka = df["Описание"][ii] #Выдергиваем - Описание, каждой строки
    for ee in func_el: #Работаем с каждым элементом long-тега (ищем и удаляем всю строку тега)
        two_e = ee
        one_e = ee.replace('/','')
        one_e = one_e.replace('>','')
        cc = stroka.count(two_e) #Находим кол-во вхождений определенного тега в строку (Описание)
        if cc>0:
            for iii in range(cc):
                k=True
                while k:
                    if stroka.find(one_e)>=0:
                        k=False
                        stroka1=stroka[0:stroka.find(one_e)].lstrip() #Оставляем часть до тега

                k=True
                while k:
                    if stroka.find(two_e)>=0:
                        k=False
                        dl=len(two_e)
                        stroka2=stroka[stroka.find(two_e)+int(dl):].rstrip() #Оставляем часть после тега
                    stroka0 = stroka1+ ' ' +stroka2 #Склеиваем строки (без тега)
                stroka=stroka0
            df["Описание"][ii]=stroka #Возвращаем значение в строку (Описание)

#print("Пройден ШАГ 1")
######################################################################################################################  

for i in range(len(df)):
    stroka = df["Описание"][i]
    if '</blockquote>' in stroka:
        k=True
        t=0
        while k:
            if stroka[len(stroka)-15-t:len(stroka)].find('</blockquote>')>=0:
                k=False
                p=stroka[len(stroka)-15-t:len(stroka)]
                #stroka2=stroka[len(stroka)-t+1:].lstrip()
                stroka2=p[p.find('</blockquote>')+13:]
            t+=15

        k=True
        t=0
        while k:
            if stroka.find('<blockquote')>=0:
                k=False
                stroka1=stroka[0:stroka.find('<blockquote')].lstrip()
            t+=5

        res = stroka1+'" Answer: " '+stroka2
        res.replace('  ',' ').lstrip()
        df["Описание"][i] = res

#print("Пройден ШАГ 2")

df.reset_index(inplace=True) #Удаляем старую индексацию
del df['index'] 
df.to_excel('RSS_all_'+ n +'.xlsx') #Сохраняем информацию в первичный файл

print('\nФайл сохранен!')

# %%
###########################################################_PART_1_###################################################  

for ii in range(len(df)): #Перебираем все строки ДатаФрейма
    stroka = df["Описание"][ii] #Выдергиваем - Описание, каждой строки
    for ee in func_el: #Работаем с каждым элементом long-тега (ищем и удаляем всю строку тега)
        two_e = ee
        one_e = ee.replace('/','')
        one_e = one_e.replace('>','')
        cc = stroka.count(two_e) #Находим кол-во вхождений определенного тега в строку (Описание)
        if cc>0:
            for iii in range(cc):
                k=True
                while k:
                    if stroka.find(one_e)>=0:
                        k=False
                        stroka1=stroka[0:stroka.find(one_e)].lstrip() #Оставляем часть до тега

                k=True
                while k:
                    if stroka.find(two_e)>=0:
                        k=False
                        dl=len(two_e)
                        stroka2=stroka[stroka.find(two_e)+int(dl):].rstrip() #Оставляем часть после тега
                    stroka0 = stroka1+ ' ' +stroka2 #Склеиваем строки (без тега)
                stroka=stroka0
            df["Описание"][ii]=stroka #Возвращаем значение в строку (Описание)

print("Пройден ШАГ 1")
######################################################################################################################  

for i in range(len(df)):
    stroka = df["Описание"][i]
    if '</blockquote>' in stroka:
        k=True
        t=0
        while k:
            if stroka[len(stroka)-15-t:len(stroka)].find('</blockquote>')>=0:
                k=False
                p=stroka[len(stroka)-15-t:len(stroka)]
                #stroka2=stroka[len(stroka)-t+1:].lstrip()
                stroka2=p[p.find('</blockquote>')+13:]
            t+=15

        k=True
        t=0
        while k:
            if stroka.find('<blockquote')>=0:
                k=False
                stroka1=stroka[0:stroka.find('<blockquote')].lstrip()
            t+=5

        res = stroka1+'" Answer: " '+stroka2
        res.replace('  ',' ').lstrip()
        df["Описание"][i] = res

print("Пройден ШАГ 2")
########################################################_PART_2_####################################################  

for i in range(len(df)-1):
    strok = df["Описание"][i]        
    for s1 in sb: #Проверяем на первое ключевое слово
        if s1.lower() in (strok.lower()):
            
            for  s2 in inp_k2: #Проверяем на второе ключевое слово
                if s2.lower() in (strok.lower()):
                    for neg1 in neg_list: #Проверяем на третье (негативное) слово
                        if neg1.lower() in (strok.lower()):
                            df2=pd.concat([df2,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше 
                         
            for  sl2 in pens_k2: #Проверяем на второе ключевое слово
                if sl2.lower() in (strok.lower()):
                    for neg2 in neg_list: #Проверяем на третье (негативное) слово
                        if neg2.lower() in (strok.lower()):
                            df3=pd.concat([df3,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше    
                        
            for  slo2 in strah_k2: #Проверяем на второе ключевое слово
                if slo2.lower() in (strok.lower()):
                    for neg3 in neg_list: #Проверяем на третье (негативное) слово
                        if neg3.lower() in (strok.lower()):
                            df4=pd.concat([df4,df[i:i+1]]) #Если все три есть в статье, то берем!
                            break #Если строка уже попала к нам, то идем дальше 
            
print("Пройден ШАГ 3\n")

df2.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df2.reset_index(inplace=True) #Удаляем старую индексацию
del df2['index'] 
print('Удовлетворяют всем условиям: ', len(df2),'!')
df2.to_excel('Инвест продукты.xlsx')
print("Программа успешно закончила работу! В части 'Инвест продукты'")

df3.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df3.reset_index(inplace=True) #Удаляем старую индексацию
del df3['index'] 
print('Удовлетворяют всем условиям: ', len(df3),'!')
df3.to_excel('Пенсия.xlsx')
print("Программа успешно закончила работу! В части 'Пенсия'")

df4.drop_duplicates(['Описание'],inplace=True) #Убираем дубликаты, сравнивая по полю "Описание"
df4.reset_index(inplace=True) #Удаляем старую индексацию
del df4['index'] 
print('Удовлетворяют всем условиям: ', len(df4),'!')
df4.to_excel('Страховка.xlsx')
print("Программа успешно закончила работу! В части 'Страховка'")
